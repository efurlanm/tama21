# %% [markdown]
# # Google Colab (GC) - Numba GPU

# %%
! nvidia-smi -L
# Out:
# GPU 0: Tesla K80 (UUID: GPU-fb13b8fb-38d9-a395-5692-6487294a4625)

# %%
from gc_nb_gpu import stencil
result = stencil(2400)
# Out:
# Heat: 750.0000 | Time: 1.4729 s | Kernel: 0.3113 s | Memory: 1.1562 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(result[600:2200,600:2200], cmap='jet')

# %%
a    = result[600:2200,600:2200]
t    = np.arange(a.shape[0])
x, y = np.meshgrid(t, t)
ax = plt.figure(figsize=(8, 8)).gca(projection='3d')
ax.plot_surface(x, y, a, cmap='jet', rcount=200, ccount=200)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Usando uma grade com 8 x 8 pontos

# %%
from gc_nb_gpu import stencil
result = stencil(8)
# Out:
# Heat: 102.6641 | Time: 0.3573 s | Kernel: 0.3467 s | Memory: 0.0105 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(result, cmap='jet')

# %%
t    = np.arange(result.shape[0])
x, y = np.meshgrid(t, t)
ax = plt.figure(figsize=(8, 8)).gca(projection='3d')
ax.plot_surface(x, y, result, cmap='jet')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Grade 24 x 24

# %%
from gc_nb_gpu import stencil
result = stencil(24)
# Out:
# Heat: 512.0860 | Time: 0.4067 s | Kernel: 0.4044 s | Memory: 0.0021 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(result, cmap='jet')

# %%
t    = np.arange(result.shape[0])
x, y = np.meshgrid(t, t)
ax = plt.figure(figsize=(8, 8)).gca(projection='3d')
ax.plot_surface(x, y, result, cmap='jet')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Grade 240 x 240

# %%
from gc_nb_gpu import stencil
result = stencil(240)
# Out:
# Heat: 749.9878 | Time: 0.4428 s | Kernel: 0.4281 s | Memory: 0.0144 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.imshow(result, cmap='jet')

# %%
t    = np.arange(result.shape[0])
x, y = np.meshgrid(t, t)
ax = plt.figure(figsize=(8, 8)).gca(projection='3d')
ax.plot_surface(x, y, result, cmap='jet')
plt.show()
